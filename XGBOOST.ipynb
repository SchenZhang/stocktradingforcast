# %%
import datetime
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import empyrical as epc
import seaborn as sns

pd.set_option("display.max_rows", 1000)
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# ## 数据

# %%
## 股票池选用2017-2021入选过HS300的所有股票

# 每日行情数据
Data = pd.read_csv('/Users/liorzhou/Desktop/python/CODING_FILE/PYTHON_FILE/Quant/prp/daily_hs300.csv')
# 资金流
Data_money = pd.read_csv('/Users/liorzhou/Desktop/python/CODING_FILE/PYTHON_FILE/Quant/prp/daily_hs300_moneyflow.csv')
# 基本面
Data_basic = pd.read_csv('/Users/liorzhou/Desktop/python/CODING_FILE/PYTHON_FILE/Quant/prp/daily_hs300_basic.csv')
# 行业分类
Industry = pd.read_csv('/Users/liorzhou/Desktop/python/CODING_FILE/PYTHON_FILE/Quant/prp/allst_basic_data.csv')

# %%
Industry_dict = dict(zip(Industry['ts_code'],Industry['industry']))
def indus(x):
    if x in Industry_dict.keys():
        return Industry_dict[x]
    else:
        return 'NOCAT'

Data['industry'] = Data['ts_code'].apply(lambda x: indus(x) )

# %%
Data.set_index(['trade_date','ts_code'],inplace = True)
Data_money.set_index(['trade_date','ts_code'],inplace = True)
Data_basic.set_index(['trade_date','ts_code'],inplace = True)

# %%
data = pd.concat([Data,Data_money],axis = 1)
data = pd.concat([data,Data_basic],axis = 1)
data.reset_index(inplace = True)

# %%
data
# Out:
#         trade_date    ts_code    open    high     low   close  pre_close  \
# 0         20170103  000001.SZ    9.11    9.18    9.09    9.16       9.10
# 1         20170103  000002.SZ   20.55   20.88   20.55   20.73      20.55
# 2         20170103  000008.SZ    9.33    9.37    9.29    9.34       9.32
# 3         20170103  000009.SZ   10.39   10.53   10.37   10.46      10.36
# 4         20170103  000027.SZ    6.88    6.94    6.88    6.92       6.87
# ...            ...        ...     ...     ...     ...     ...        ...
# 438859    20210201  603993.SH    6.01    6.10    5.85    5.96       6.06
# 438860    20210201  688008.SH   87.59   88.38   83.50   87.88      87.51
# 438861    20210201  688009.SH    5.75    5.80    5.72    5.78       5.76
# 438862    20210201  688012.SH  152.00  160.50  152.00  157.04     153.55
# 438863    20210201  688036.SH  200.00  200.00  180.01  187.14     206.00
#
#         change  pct_chg         vol  ...  net_mf_amount        pe       pb  \
# 0         0.06   0.6600   459840.49  ...        6531.67    7.1933   0.8822
# 1         0.18   0.8800   217016.69  ...        1882.25   12.6296   2.2792
# 2         0.02   0.2100    47814.12  ...        -745.18  141.3076   4.3392
# 3         0.10   0.9700   263917.73  ...         -84.47   28.4941   4.9545
# 4         0.05   0.7300    70835.84  ...        -546.03   15.3231   1.2811
# ...        ...      ...         ...  ...            ...       ...      ...
# 438859   -0.10  -1.6502  2767916.85  ...      -23201.81   69.3217   3.1887
# 438860    0.37   0.4228    64428.44  ...       -3612.55  106.4342  12.4996
# 438861    0.02   0.3472   141716.27  ...         437.23   16.0407   1.5818
# 438862    3.49   2.2729    36087.09  ...        3438.03  445.4438  20.4839
# 438863  -18.86  -9.1553    50616.62  ...       -9208.27   83.4839  15.3946
#
#              ps  dv_ratio   total_share   float_share   free_share  \
# 0        1.6356    1.3900  1.717041e+06  1.463118e+06  761028.1784
# 1        1.1703    3.4732  1.103915e+06  9.708108e+05  709927.8040
# 2       20.2589       NaN  2.809078e+05  1.495229e+05   93132.6488
# 3        4.6209    0.4957  2.149345e+05  2.120066e+05  174426.4255
# 4        2.4649    2.8902  3.964492e+05  3.964492e+05  106611.9179
# ...         ...       ...           ...           ...          ...
# 438859   1.8745    0.7215  2.159924e+06  1.766577e+06  700277.2183
# 438860  57.1365       NaN  1.129814e+05  4.202018e+04   42020.1823
# 438861   1.4697       NaN  1.058982e+06  1.980592e+05  198059.1576
# 438862  43.1417       NaN  5.348622e+04  2.454025e+04   24540.2535
# 438863   5.9067       NaN  8.000000e+04  3.891747e+04   15221.3764
#
#             total_mv       circ_mv
# 0       1.572810e+07  1.340216e+07
# 1       2.288416e+07  2.012491e+07
# 2       2.623679e+06  1.396543e+06
# 3       2.248215e+06  2.217589e+06
# 4       2.743428e+06  2.743428e+06
# ...              ...           ...
# 438859  1.287315e+07  1.052880e+07
# 438860  9.928804e+06  3.692734e+06
# 438861  6.120915e+06  1.144782e+06
# 438862  8.399477e+06  3.853801e+06
# 438863  1.497120e+07  7.283016e+06
#
# [438864 rows x 47 columns]

# %%
data.columns
# Out:
# Index(['trade_date', 'ts_code', 'open', 'high', 'low', 'close', 'pre_close',
#        'change', 'pct_chg', 'vol', 'amount', 'turnover_rate', 'volume_ratio',
#        'ma5', 'ma_v_5', 'ma20', 'ma_v_20', 'ma50', 'ma_v_50', 'industry',
#        'buy_sm_vol', 'buy_sm_amount', 'sell_sm_vol', 'sell_sm_amount',
#        'buy_md_vol', 'buy_md_amount', 'sell_md_vol', 'sell_md_amount',
#        'buy_lg_vol', 'buy_lg_amount', 'sell_lg_vol', 'sell_lg_amount',
#        'buy_elg_vol', 'buy_elg_amount', 'sell_elg_vol', 'sell_elg_amount',
#        'net_mf_vol', 'net_mf_amount', 'pe', 'pb', 'ps', 'dv_ratio',
#        'total_share', 'float_share', 'free_share', 'total_mv', 'circ_mv'],
#       dtype='object')

# %%
data.sort_values(['ts_code','trade_date'],inplace = True)

# %% [markdown]
# ## Factor 计算

# %%
## 收益率
data['Return'] = data.groupby('ts_code')['close'].apply(lambda x: (x - x.shift(1))/x.shift(1))
data['Return_std'] = data['Return'].rolling(5).std()

# %%
## 换手率变化幅度
data['trchange'] = data.groupby('ts_code')['turnover_rate'].apply(lambda x: (x - x.shift(1))/x.shift(1))

# %%
## 隔夜收益率因子
data['over_night'] = (data['open'] - data['pre_close'])/data['pre_close']

# %%
## close超过5日均线的比例 
data['MA5_per'] = (data['close'] - data['ma5']) / data['ma5']
data['VMA5_per'] = (data['vol'] - data['ma_v_5']) / data['ma_v_5']

# %%
## close超过20日均线的比例 
data['MA20_per'] = (data['close'] - data['ma20']) / data['ma20']
data['VMA20_per'] = (data['vol'] - data['ma_v_20']) / data['ma_v_20']

# %%
## close超过50日均线的比例 
data['MA50_per'] = (data['close'] - data['ma50']) / data['ma50']
data['VMA50_per'] = (data['vol'] - data['ma_v_50']) / data['ma_v_50']

# %%
## MACD
data['EMA_12'] = data.groupby('ts_code')['close'].apply(lambda x :x.ewm(span = 12,adjust=False).mean())
data['EMA_26'] = data.groupby('ts_code')['close'].apply(lambda x :x.ewm(span = 26,adjust=False).mean())
data['DIF'] = data['EMA_12'] - data['EMA_26']
data['DEA'] = data.groupby('ts_code')['DIF'].apply(lambda x :x.ewm(span = 9,adjust = False).mean())
data['MCAD_new'] = np.sign(data['DIF']*data['DEA'])*(data['DIF'] - data['DEA'])

# %%
## VOSC
data['VOSC'] = (data['ma_v_5'] - data['ma_v_20'])/ data['ma_v_20']

# %%
## 上下行波动率差
data['high_change'] = data.groupby('ts_code')['high'].apply(lambda x: (x - x.shift(1))/x.shift(1))
data['low_change'] = data.groupby('ts_code')['low'].apply(lambda x: (x - x.shift(1))/x.shift(1))
data['uplow_change'] = data['high_change'] - data['low_change']

# %%
## 特大单买入量与5日平均的差 机构
data['buy_elg_vol_5ma'] = data.groupby('ts_code')['buy_elg_vol'].apply(lambda x : x.rolling(5).mean())
data['buy_elg_vol_5per'] = (data['buy_elg_vol'] - data['buy_elg_vol_5ma']) / data['buy_elg_vol_5ma']
data['buy_elg_vol_5per'] = data.groupby('industry')['buy_elg_vol_5per'].apply(lambda x: x - np.mean(x))

# %%
## 特大单卖出量与5日平均的差 机构
data['sell_elg_vol_5ma'] = data.groupby('ts_code')['sell_elg_vol'].apply(lambda x : x.rolling(5).mean())
data['sell_elg_vol_5per'] = (data['sell_elg_vol'] - data['sell_elg_vol_5ma']) / data['sell_elg_vol_5ma']
data['sell_elg_vol_5per'] = data.groupby('industry')['sell_elg_vol_5per'].apply(lambda x: x - np.mean(x))

# %%
## 差值
data['diff_sell_elg_vol_5per'] = data['buy_elg_vol_5per'] - data['sell_elg_vol_5per']

# %%
## 净流入量涨跌幅度
data['net_mf_vol_chg'] = data.groupby('ts_code')['net_mf_vol'].apply(lambda x: (x - x.shift(1))/x.shift(1))

# %%
## 小市值
data['mktc_inv'] = 1 / data['circ_mv'] * 10**7

# %%
data
# Out:
#         trade_date    ts_code    open    high     low   close  pre_close  \
# 0         20170103  000001.SZ    9.11    9.18    9.09    9.16       9.10
# 409       20170104  000001.SZ    9.15    9.18    9.14    9.16       9.16
# 818       20170105  000001.SZ    9.17    9.18    9.15    9.17       9.16
# 1225      20170106  000001.SZ    9.17    9.17    9.11    9.13       9.17
# 1631      20170109  000001.SZ    9.13    9.17    9.11    9.15       9.13
# ...            ...        ...     ...     ...     ...     ...        ...
# 436986    20210126  688036.SH  204.59  204.59  192.06  197.00     207.51
# 437455    20210127  688036.SH  197.01  199.50  183.88  190.00     197.00
# 437925    20210128  688036.SH  186.81  195.58  183.00  185.20     190.00
# 438394    20210129  688036.SH  186.97  208.80  182.00  206.00     185.20
# 438863    20210201  688036.SH  200.00  200.00  180.01  187.14     206.00
#
#         change  pct_chg        vol  ...  high_change  low_change  \
# 0         0.06   0.6600  459840.49  ...          NaN         NaN
# 409       0.00   0.0000  449329.53  ...     0.000000    0.005501
# 818       0.01   0.1100  344372.91  ...     0.000000    0.001094
# 1225     -0.04  -0.4400  358154.20  ...    -0.001089   -0.004372
# 1631      0.02   0.2200  361081.57  ...     0.000000    0.000000
# ...        ...      ...        ...  ...          ...         ...
# 436986  -10.51  -5.0648   32494.23  ...    -0.034907    0.027059
# 437455   -7.00  -3.5533   32477.26  ...    -0.024879   -0.042591
# 437925   -4.80  -2.5263   26012.65  ...    -0.019649   -0.004786
# 438394   20.80  11.2311   46802.47  ...     0.067594   -0.005464
# 438863  -18.86  -9.1553   50616.62  ...    -0.042146   -0.010934
#
#         uplow_change  buy_elg_vol_5ma  buy_elg_vol_5per  sell_elg_vol_5ma  \
# 0                NaN              NaN               NaN               NaN
# 409        -0.005501              NaN               NaN               NaN
# 818        -0.001094              NaN               NaN               NaN
# 1225        0.003282              NaN               NaN               NaN
# 1631        0.000000          97452.2          0.187703          109288.4
# ...              ...              ...               ...               ...
# 436986     -0.061966           5821.0         -0.605568            5600.0
# 437455      0.017712           4677.0         -0.277441            5389.8
# 437925     -0.014863           3630.0         -0.552358            4517.0
# 438394      0.073058           3867.6          0.473983            5149.6
# 438863     -0.031212           4665.8          1.169298            5385.0
#
#         sell_elg_vol_5per  diff_sell_elg_vol_5per  net_mf_vol_chg  mktc_inv
# 0                     NaN                     NaN             NaN  0.746148
# 409                   NaN                     NaN       -1.096482  0.746148
# 818                   NaN                     NaN       -3.516705  0.745335
# 1225                  NaN                     NaN       -8.909091  0.748600
# 1631            -0.128633                0.316336       -0.721204  0.645996
# ...                   ...                     ...             ...       ...
# 436986          -0.119596               -0.485972       -0.991916  1.304335
# 437455          -0.141115               -0.136327      -69.029412  1.352389
# 437925          -0.318466               -0.233892        0.328578  1.387441
# 438394           0.290507                0.183476       -5.268793  1.247349
# 438863           0.351028                0.818269       -1.372465  1.373058
#
# [438864 rows x 73 columns]

# %%
## Y：预测值：open的涨跌幅
data['Y'] = data.groupby('ts_code')['open'].apply(lambda x: (x - x.shift(1))/x.shift(1))
print(data)
data['Y'] = data.groupby('ts_code')['Y'].apply(lambda x:x.shift(-2))
# Out:
#         trade_date    ts_code    open    high     low   close  pre_close  \
# 0         20170103  000001.SZ    9.11    9.18    9.09    9.16       9.10
# 409       20170104  000001.SZ    9.15    9.18    9.14    9.16       9.16
# 818       20170105  000001.SZ    9.17    9.18    9.15    9.17       9.16
# 1225      20170106  000001.SZ    9.17    9.17    9.11    9.13       9.17
# 1631      20170109  000001.SZ    9.13    9.17    9.11    9.15       9.13
# ...            ...        ...     ...     ...     ...     ...        ...
# 436986    20210126  688036.SH  204.59  204.59  192.06  197.00     207.51
# 437455    20210127  688036.SH  197.01  199.50  183.88  190.00     197.00
# 437925    20210128  688036.SH  186.81  195.58  183.00  185.20     190.00
# 438394    20210129  688036.SH  186.97  208.80  182.00  206.00     185.20
# 438863    20210201  688036.SH  200.00  200.00  180.01  187.14     206.00
#
#         change  pct_chg        vol  ...  low_change  uplow_change  \
# 0         0.06   0.6600  459840.49  ...         NaN           NaN
# 409       0.00   0.0000  449329.53  ...    0.005501     -0.005501
# 818       0.01   0.1100  344372.91  ...    0.001094     -0.001094
# 1225     -0.04  -0.4400  358154.20  ...   -0.004372      0.003282
# 1631      0.02   0.2200  361081.57  ...    0.000000      0.000000
# ...        ...      ...        ...  ...         ...           ...
# 436986  -10.51  -5.0648   32494.23  ...    0.027059     -0.061966
# 437455   -7.00  -3.5533   32477.26  ...   -0.042591      0.017712
# 437925   -4.80  -2.5263   26012.65  ...   -0.004786     -0.014863
# 438394   20.80  11.2311   46802.47  ...   -0.005464      0.073058
# 438863  -18.86  -9.1553   50616.62  ...   -0.010934     -0.031212
#
#         buy_elg_vol_5ma  buy_elg_vol_5per  sell_elg_vol_5ma  \
# 0                   NaN               NaN               NaN
# 409                 NaN               NaN               NaN
# 818                 NaN               NaN               NaN
# 1225                NaN               NaN               NaN
# 1631            97452.2          0.187703          109288.4
# ...                 ...               ...               ...
# 436986           5821.0         -0.605568            5600.0
# 437455           4677.0         -0.277441            5389.8
# 437925           3630.0         -0.552358            4517.0
# 438394           3867.6          0.473983            5149.6
# 438863           4665.8          1.169298            5385.0
#
#         sell_elg_vol_5per  diff_sell_elg_vol_5per  net_mf_vol_chg  mktc_inv  \
# 0                     NaN                     NaN             NaN  0.746148
# 409                   NaN                     NaN       -1.096482  0.746148
# 818                   NaN                     NaN       -3.516705  0.745335
# 1225                  NaN                     NaN       -8.909091  0.748600
# 1631            -0.128633                0.316336       -0.721204  0.645996
# ...                   ...                     ...             ...       ...
# 436986          -0.119596               -0.485972       -0.991916  1.304335
# 437455          -0.141115               -0.136327      -69.029412  1.352389
# 437925          -0.318466               -0.233892        0.328578  1.387441
# 438394           0.290507                0.183476       -5.268793  1.247349
# 438863           0.351028                0.818269       -1.372465  1.373058
#
#                Y
# 0            NaN
# 409     0.004391
# 818     0.002186
# 1225    0.000000
# 1631   -0.004362
# ...          ...
# 436986  0.071152
# 437455 -0.037050
# 437925 -0.051774
# 438394  0.000856
# 438863  0.069690
#
# [438864 rows x 74 columns]

# %%
# 去除Y为nan的数据
data.dropna(subset = ['Y'],inplace = True)
data
# Out:
#         trade_date    ts_code    open    high     low   close  pre_close  \
# 0         20170103  000001.SZ    9.11    9.18    9.09    9.16       9.10
# 409       20170104  000001.SZ    9.15    9.18    9.14    9.16       9.16
# 818       20170105  000001.SZ    9.17    9.18    9.15    9.17       9.16
# 1225      20170106  000001.SZ    9.17    9.17    9.11    9.13       9.17
# 1631      20170109  000001.SZ    9.13    9.17    9.11    9.15       9.13
# ...            ...        ...     ...     ...     ...     ...        ...
# 436048    20210122  688036.SH  191.01  196.17  182.00  191.00     192.06
# 436517    20210125  688036.SH  191.00  211.99  187.00  207.51     191.00
# 436986    20210126  688036.SH  204.59  204.59  192.06  197.00     207.51
# 437455    20210127  688036.SH  197.01  199.50  183.88  190.00     197.00
# 437925    20210128  688036.SH  186.81  195.58  183.00  185.20     190.00
#
#         change  pct_chg        vol  ...  low_change  uplow_change  \
# 0         0.06   0.6600  459840.49  ...         NaN           NaN
# 409       0.00   0.0000  449329.53  ...    0.005501     -0.005501
# 818       0.01   0.1100  344372.91  ...    0.001094     -0.001094
# 1225     -0.04  -0.4400  358154.20  ...   -0.004372      0.003282
# 1631      0.02   0.2200  361081.57  ...    0.000000      0.000000
# ...        ...      ...        ...  ...         ...           ...
# 436048   -1.06  -0.5519   36313.41  ...    0.067449     -0.061397
# 436517   16.51   8.6440   39551.87  ...    0.027473      0.053172
# 436986  -10.51  -5.0648   32494.23  ...    0.027059     -0.061966
# 437455   -7.00  -3.5533   32477.26  ...   -0.042591      0.017712
# 437925   -4.80  -2.5263   26012.65  ...   -0.004786     -0.014863
#
#         buy_elg_vol_5ma  buy_elg_vol_5per  sell_elg_vol_5ma  \
# 0                   NaN               NaN               NaN
# 409                 NaN               NaN               NaN
# 818                 NaN               NaN               NaN
# 1225                NaN               NaN               NaN
# 1631            97452.2          0.187703          109288.4
# ...                 ...               ...               ...
# 436048           5188.4         -0.132536            4938.4
# 436517           5688.0          0.076160            5646.0
# 436986           5821.0         -0.605568            5600.0
# 437455           4677.0         -0.277441            5389.8
# 437925           3630.0         -0.552358            4517.0
#
#         sell_elg_vol_5per  diff_sell_elg_vol_5per  net_mf_vol_chg  mktc_inv  \
# 0                     NaN                     NaN             NaN  0.746148
# 409                   NaN                     NaN       -1.096482  0.746148
# 818                   NaN                     NaN       -3.516705  0.745335
# 1225                  NaN                     NaN       -8.909091  0.748600
# 1631            -0.128633                0.316336       -0.721204  0.645996
# ...                   ...                     ...             ...       ...
# 436048          -0.294191                0.161655       -1.392717  1.345309
# 436517           0.079457               -0.003297       -3.805871  1.238273
# 436986          -0.119596               -0.485972       -0.991916  1.304335
# 437455          -0.141115               -0.136327      -69.029412  1.352389
# 437925          -0.318466               -0.233892        0.328578  1.387441
#
#                Y
# 0       0.002186
# 409     0.000000
# 818    -0.004362
# 1225    0.002191
# 1631   -0.001093
# ...          ...
# 436048  0.071152
# 436517 -0.037050
# 436986 -0.051774
# 437455  0.000856
# 437925  0.069690
#
# [437912 rows x 74 columns]

# %%
## 生成因子集
FACTOR = data[['trade_date','ts_code','close','open','vol','volume_ratio','trchange','over_night','MA5_per','MA20_per',
               'VMA5_per','VMA50_per','MA50_per','MCAD_new','VOSC','uplow_change','pct_chg','Return_std','high_change',
               'diff_sell_elg_vol_5per','net_mf_vol_chg','mktc_inv','pe','pb','ps','dv_ratio','Y']]

FACTOR['year'] = FACTOR['trade_date'].apply(lambda x : int(str(x)[:4]))
FACTOR['month'] = FACTOR['trade_date'].apply(lambda x : int(str(x)[4:6]))
FACTOR['trade_date'] = FACTOR['trade_date'].apply(lambda x : datetime.datetime.strptime(str(x),"%Y%m%d").date())
FACTOR['weekday'] = FACTOR['trade_date'].apply(lambda x :  datetime.date.weekday(x))
#FACTOR['code'] = FACTOR['ts_code'].apply(lambda x : int(x[:-3]) )

# %%
FACTOR
# Out:
#         trade_date    ts_code   close    open        vol  volume_ratio  \
# 0       2017-01-03  000001.SZ    9.16    9.11  459840.49          1.48
# 409     2017-01-04  000001.SZ    9.16    9.15  449329.53          1.32
# 818     2017-01-05  000001.SZ    9.17    9.17  344372.91          0.91
# 1225    2017-01-06  000001.SZ    9.13    9.17  358154.20          0.95
# 1631    2017-01-09  000001.SZ    9.15    9.13  361081.57          0.94
# ...            ...        ...     ...     ...        ...           ...
# 436048  2021-01-22  688036.SH  191.00  191.01   36313.41          0.94
# 436517  2021-01-25  688036.SH  207.51  191.00   39551.87          1.02
# 436986  2021-01-26  688036.SH  197.00  204.59   32494.23          0.81
# 437455  2021-01-27  688036.SH  190.00  197.01   32477.26          0.80
# 437925  2021-01-28  688036.SH  185.20  186.81   26012.65          0.69
#
#         trchange  over_night   MA5_per  MA20_per  ...  net_mf_vol_chg  \
# 0            NaN    0.001099       NaN       NaN  ...             NaN
# 409    -0.022908   -0.001092       NaN       NaN  ...       -1.096482
# 818    -0.233474    0.001092       NaN       NaN  ...       -3.516705
# 1225    0.039932    0.000000       NaN       NaN  ...       -8.909091
# 1631   -0.128268    0.000000 -0.000437       NaN  ...       -0.721204
# ...          ...         ...       ...       ...  ...             ...
# 436048 -0.239961   -0.005467  0.085326  0.214939  ...       -1.392717
# 436517  0.089165    0.000000  0.124484  0.291405  ...       -3.805871
# 436986 -0.178392   -0.014072  0.021180  0.204668  ...       -0.991916
# 437455 -0.000599    0.000051 -0.028203  0.145023  ...      -69.029412
# 437925 -0.199041   -0.016789 -0.046059  0.102739  ...        0.328578
#
#         mktc_inv       pe       pb      ps  dv_ratio         Y  year  month  \
# 0       0.746148   7.1933   0.8822  1.6356      1.39  0.002186  2017      1
# 409     0.746148   7.1933   0.8822  1.6356      1.39  0.000000  2017      1
# 818     0.745335   7.2011   0.8832  1.6374      1.39 -0.004362  2017      1
# 1225    0.748600   7.1697   0.8793  1.6302      1.40  0.002191  2017      1
# 1631    0.645996   7.1854   0.8813  1.6338      1.39 -0.001093  2017      1
# ...          ...      ...      ...     ...       ...       ...   ...    ...
# 436048  1.345309  85.2059  15.7122  6.0286       NaN  0.071152  2021      1
# 436517  1.238273  92.5711  17.0703  6.5497       NaN -0.037050  2021      1
# 436986  1.304335  87.8825  16.2057  6.2180       NaN -0.051774  2021      1
# 437455  1.352389  84.7598  15.6299  5.9970       NaN  0.000856  2021      1
# 437925  1.387441  82.6185  15.2350  5.8455       NaN  0.069690  2021      1
#
#         weekday
# 0             1
# 409           2
# 818           3
# 1225          4
# 1631          0
# ...         ...
# 436048        4
# 436517        0
# 436986        1
# 437455        2
# 437925        3
#
# [437912 rows x 30 columns]

# %%
## 因子集处理
FACTOR.fillna(method = 'ffill',inplace = True)
FACTOR.replace(np.inf,np.nan,inplace = True)
FACTOR.replace(-np.inf,np.nan,inplace = True) 
FACTOR.dropna(axis = 0,inplace= True)
FACTOR.set_index(['trade_date','ts_code'],inplace = True)

# %%
FACTOR_1 = FACTOR.loc[:,~(FACTOR.columns == 'Y')]
Y_or = FACTOR.loc[:,'Y']

# %%
Y_or
# Out:
# trade_date  ts_code
# 2017-03-20  000001.SZ   -0.005405
# 2017-03-21  000001.SZ   -0.004348
# 2017-03-22  000001.SZ    0.004367
# 2017-03-23  000001.SZ   -0.008696
# 2017-03-24  000001.SZ    0.004386
#                            ...
# 2021-01-22  688036.SH    0.071152
# 2021-01-25  688036.SH   -0.037050
# 2021-01-26  688036.SH   -0.051774
# 2021-01-27  688036.SH    0.000856
# 2021-01-28  688036.SH    0.069690
# Name: Y, Length: 437850, dtype: float64

# %%
Y = (Y_or>0).map(int)
Y
# Out:
# trade_date  ts_code
# 2017-03-20  000001.SZ    0
# 2017-03-21  000001.SZ    0
# 2017-03-22  000001.SZ    1
# 2017-03-23  000001.SZ    0
# 2017-03-24  000001.SZ    1
#                         ..
# 2021-01-22  688036.SH    1
# 2021-01-25  688036.SH    0
# 2021-01-26  688036.SH    0
# 2021-01-27  688036.SH    1
# 2021-01-28  688036.SH    1
# Name: Y, Length: 437850, dtype: int64

# %% [markdown]
# ## 因子筛选

# %%
## 相关性检验
figure = plt.figure(figsize = (10,6))
sns.heatmap(FACTOR_1.corr(),cmap = 'GnBu',linewidths = 0.5,center = 0.7)
# Out:
# <AxesSubplot:>

# %%
figure = plt.figure(figsize = (10,6))
sns.heatmap(FACTOR_1.corr() > 0.6,cmap = 'GnBu',linewidths = 0.5,center = 0.7)
# Out:
# <AxesSubplot:>

# %%
X = FACTOR_1.copy()
#ts_code = X['ts_code']
X.drop(['close','MA20_per','MA50_per','pct_chg','high_change','VOSC','year','dv_ratio'],axis = 1 ,inplace= True)
X
#X = np.array(X)
# Out:
#                         open        vol  volume_ratio  trchange  over_night  \
# trade_date ts_code
# 2017-03-20 000001.SZ    9.29  715021.77          0.96 -0.548553   -0.002148
# 2017-03-21 000001.SZ    9.25  554648.74          0.71 -0.224326    0.000000
# 2017-03-22 000001.SZ    9.20  566123.63          0.70  0.020744   -0.004329
# 2017-03-23 000001.SZ    9.16  433588.29          0.53 -0.234011    0.000000
# 2017-03-24 000001.SZ    9.20  710827.87          0.92  0.639485    0.000000
# ...                      ...        ...           ...       ...         ...
# 2021-01-22 688036.SH  191.01   36313.41          0.94 -0.239961   -0.005467
# 2021-01-25 688036.SH  191.00   39551.87          1.02  0.089165    0.000000
# 2021-01-26 688036.SH  204.59   32494.23          0.81 -0.178392   -0.014072
# 2021-01-27 688036.SH  197.01   32477.26          0.80 -0.000599    0.000051
# 2021-01-28 688036.SH  186.81   26012.65          0.69 -0.199041   -0.016789
#
#                        MA5_per  VMA5_per  VMA50_per  MCAD_new  uplow_change  \
# trade_date ts_code
# 2017-03-20 000001.SZ -0.015957 -0.079924   0.532671 -0.024184     -0.007254
# 2017-03-21 000001.SZ -0.012821 -0.312845   0.184093  0.029835     -0.003201
# 2017-03-22 000001.SZ -0.014630 -0.302012   0.202594  0.037089      0.002202
# 2017-03-23 000001.SZ -0.003466 -0.437341  -0.082424  0.037224      0.001075
# 2017-03-24 000001.SZ -0.001955  0.192580   0.482157 -0.035996     -0.001093
# ...                        ...       ...        ...       ...           ...
# 2021-01-22 688036.SH  0.085326 -0.067452  -0.104003  3.682787     -0.061397
# 2021-01-25 688036.SH  0.124484 -0.019248  -0.021101  4.872000      0.053172
# 2021-01-26 688036.SH  0.021180 -0.201959  -0.184079  4.614307     -0.061966
# 2021-01-27 688036.SH -0.028203 -0.139057  -0.180490  3.676711      0.017712
# 2021-01-28 688036.SH -0.046059 -0.220475  -0.336834  2.494136     -0.014863
#
#                       Return_std  diff_sell_elg_vol_5per  net_mf_vol_chg  \
# trade_date ts_code
# 2017-03-20 000001.SZ    0.010994                0.291413       -0.698966
# 2017-03-21 000001.SZ    0.010906               -0.007562       -0.622214
# 2017-03-22 000001.SZ    0.009881               -0.126403        1.946550
# 2017-03-23 000001.SZ    0.009922                0.218248       -1.220456
# 2017-03-24 000001.SZ    0.005114               -0.299562       -5.283444
# ...                          ...                     ...             ...
# 2021-01-22 688036.SH    0.078417                0.161655       -1.392717
# 2021-01-25 688036.SH    0.080126               -0.003297       -3.805871
# 2021-01-26 688036.SH    0.077546               -0.485972       -0.991916
# 2021-01-27 688036.SH    0.065756               -0.136327      -69.029412
# 2021-01-28 688036.SH    0.054272               -0.233892        0.328578
#
#                       mktc_inv       pe       pb      ps  month  weekday
# trade_date ts_code
# 2017-03-20 000001.SZ  0.639013   7.0280   0.8716  1.4745      3        0
# 2017-03-21 000001.SZ  0.639704   7.0204   0.8707  1.4729      3        1
# 2017-03-22 000001.SZ  0.645291   6.9596   0.8631  1.4602      3        2
# 2017-03-23 000001.SZ  0.642486   6.9900   0.8669  1.4665      3        3
# 2017-03-24 000001.SZ  0.643185   6.9824   0.8660  1.4649      3        4
# ...                        ...      ...      ...     ...    ...      ...
# 2021-01-22 688036.SH  1.345309  85.2059  15.7122  6.0286      1        4
# 2021-01-25 688036.SH  1.238273  92.5711  17.0703  6.5497      1        0
# 2021-01-26 688036.SH  1.304335  87.8825  16.2057  6.2180      1        1
# 2021-01-27 688036.SH  1.352389  84.7598  15.6299  5.9970      1        2
# 2021-01-28 688036.SH  1.387441  82.6185  15.2350  5.8455      1        3
#
# [437850 rows x 19 columns]

# %%
figure = plt.figure(figsize = (10,6))
sns.heatmap(X.corr() > 0.6,cmap = 'GnBu',linewidths = 0.5,center = 0.7)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## XGBOOST 算法

# %% [markdown]
# 二分类算法，预测T+2交易日open相对于T+1交易日open的涨跌。 1为涨，0为跌。

# %%
lim = datetime.datetime.strptime('20200501','%Y%m%d')

X_train = X[X.index.get_level_values(0)<lim ]
X_test = X[X.index.get_level_values(0)>=lim ]

y_train = Y[Y.index.get_level_values(0)<lim ]
y_test = Y[Y.index.get_level_values(0)>=lim ]

# %%
y_train
# Out:
# trade_date  ts_code
# 2017-03-20  000001.SZ    0
# 2017-03-21  000001.SZ    0
# 2017-03-22  000001.SZ    1
# 2017-03-23  000001.SZ    0
# 2017-03-24  000001.SZ    1
#                         ..
# 2020-04-24  688036.SH    0
# 2020-04-27  688036.SH    0
# 2020-04-28  688036.SH    1
# 2020-04-29  688036.SH    1
# 2020-04-30  688036.SH    1
# Name: Y, Length: 352046, dtype: int64

# %%
import xgboost as xgb

# %%
dtrain = xgb.DMatrix(X_train, y_train)
num_rounds = 110
params = {
'booster': 'gbtree',
'objective': 'binary:hinge',
#'num_class': 2,
'gamma': 0,
'max_depth': 9,
'reg_alpha':0.1,
'lambda': 1,
'subsample': 0.7,
'colsample_bytree': 0.8,
'min_child_weight': 6,
'verbosity':0,
'eta': 0.1,
'seed': 5,
#'nthread': 60,
}
plst = list(params.items())
model = xgb.train(plst, dtrain, num_rounds)
# 对测试集进行预测
dtest = xgb.DMatrix(X_test)
y_pred = model.predict(dtest)

# %%
def score(y_test, y_pred):
    y_test_v = y_test.values
    return sum((y_test_v == y_pred)) / len(y_pred)

# %%
print(score(y_test,y_pred))
xgb.plot_importance(model)
plt.show()
# Out:
# 0.5427952076826256

# %%
y_pred
# Out:
# array([0., 1., 0., ..., 1., 1., 1.], dtype=float32)

# %%
np.sum(( y_test == 1))/len(y_pred)
# Out:
# 0.46694792783553213

# %%
np.sum((y_pred - y_test) == 1)/len(y_pred) # 假阳
# Out:
# 0.19064379283017108

# %%
np.sum((y_pred - y_test) == -1)/len(y_pred) # 假阴
# Out:
# 0.2665609994872034

# %%
np.sum(((y_pred - y_test) == 0)&(y_pred ==1))/len(y_pred) # 真阳
# Out:
# 0.20038692834832875

# %%
np.sum(((y_pred - y_test) == 0)&(y_pred ==0))/len(y_pred) # 真阴
# Out:
# 0.3424082793342968

# %% [markdown]
# #### 参数寻优

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

#max_depth = [8,9,10,12,13]
eta = [0.01,0.05,0.1]
min_child_weight = [3,4,5,6]
#subsample = [0.7,0.8,0.9,1]
#colsample_bytree = [0.7,0.8,0.9,1]
reg_alpha = [0.01,0.1,0.5,1]


param_grid = dict(reg_alpha =reg_alpha)

params1 = {
'booster': 'gbtree',
'objective': 'binary:hinge',
'n_estimators':110,
'gamma': 0,
'max_depth': 9,
'reg_alpha':1,
'lambda': 1,
'subsample': 0.9,
'colsample_bytree': 1,
'min_child_weight': 6 ,
'verbosity':0,
'eta': 0.1,
'seed': 5,
#'nthread': 60,
}

kfold = StratifiedKFold(n_splits=3, shuffle=True, random_state=7)
model = xgb.XGBClassifier(**params1)

grid_search = GridSearchCV(model, param_grid, scoring="accuracy", n_jobs=-1, cv=kfold, verbose=1)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  12 | elapsed:  5.4min remaining: 27.0min
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:  6.2min finished
# /Users/liorzhou/opt/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Best: 0.624975 using {'reg_alpha': 0.1}

# %% [markdown]
# ## 回测

# %%
#### backtest v2 ####
# 以信号下一周期的open买入卖出，即每周期收盘后得到信号，在下一周期开始的时候进行交易, 以此规避 T+1
# 考虑手续费，不考虑涨跌停
# benchmark：HS300指数


def backtest(signal_df):
    '''输入signal格式如上'''
    
    sig = signal_df.copy()
    date_list = sorted(list(set(sig.index.to_list())))
    
    result = pd.DataFrame(index = date_list,columns = ['cash','capital','turn_over','hold'])
    sig['open'] = sig[['open','ts_code']].groupby('ts_code').shift(-1) # 下一周期的open前移
    sig['compare'] = sig['compare']/sig['open']   # 每天 capital*权重/open = 股数
     
    signal = sig.copy()
    signal = signal.replace(0,np.nan).dropna() # 删除信号为0，即不操作的日子
    
    fee = 1.0*10**-3 # 印花税率
    fee_twoside = 6.4*10**-4 # 双边过户费率
    
    hold = {}  # symbol: amount持股量
    result.iloc[0,:] = [100000,100000,0,hold]
    
    for i in range(len(date_list)-1):
        
        day = date_list[i]
        trday_signal = signal[signal.index == day]
        
   
        today_sym = sig[sig.index == day]['ts_code'].to_list()
        today_open = sig[sig.index == day]['open'].to_list()
        today_inf = dict(zip(today_sym,today_open))    # 当日所有股票的open信息
        #print(today_inf)
       
        
        if trday_signal.empty :
            
            ## 无交易信号
            result.cash.iloc[i+1] = result.cash.iloc[i]
            result.turn_over.iloc[i+1] = 0
            result.hold.iloc[i+1] = [hold]
            
                
            hold_amount = {k:v*hold[k] for k,v in today_inf.items() if k in hold.keys() } # 更新capital
            hold_cap = sum(hold_amount.values())
            result.capital.iloc[i+1] = hold_cap + result.cash.iloc[i+1]
            #print(date_list[i+1],'no signal')
            
        else:
            ## 下一周期的目标持仓 trday_signal
            tar_hold = trday_signal['ts_code'].to_list()
             # 按照昨日capital分配股数
            tar_open = [result.capital.iloc[i]*x for x in trday_signal['compare'].to_list()]  
            tar = dict(zip(tar_hold,tar_open))
           
            ## 卖
            
            sell_inhold = {}
            curr_hold = hold.copy()
            for k,v in curr_hold.items():
                if k not in tar.keys():
                    sell_inhold[k] = v
                    del hold[k]
                else:
                     if v > tar[k]:
                        sell_inhold[k] = v - tar[k]
                        hold[k] = tar[k]
            
            
            sell_amount = {k:v*today_inf[k] for k,v in sell_inhold.items() if k in today_inf.keys()}
            sell_amount = {k: sell_amount[k] for k in sell_amount if not np.isnan(sell_amount[k])}
            
            if sell_amount:
                sell_cash = sum(sell_amount.values())  # 卖出得到的cash
            else:
                sell_cash = 0 
                
            cash = result.cash.iloc[i] + sell_cash*(1-fee-fee_twoside) # 手上有的cash  
           
            
            ## 买

            buy = {}
            curr_hold = hold.copy()
        
            for k,v in tar.items():
                if k not in curr_hold:
                    buy[k] = v
                    hold[k] = v  
                else:
                    if curr_hold[k] < tar[k]:
                        buy[k] = tar[k] - curr_hold[k]
                        hold[k] = tar[k]
                        
            
            buy_amount = {k:v*today_inf[k] for k,v in buy.items()}
            buy_amount = {k: buy_amount[k] for k in buy_amount if not np.isnan(buy_amount[k])}
            
         
            if  buy_amount:
                buy_cash = sum(buy_amount.values())
            else:
                buy_cash =0
            
            cash = cash - buy_cash * (1+fee_twoside)
                
            ## 记录
            hold = {k: hold[k] for k in hold if not np.isnan(hold[k])}
            
            result.cash.iloc[i+1] =  cash
            result.hold.iloc[i+1] = [hold]
            
            hold_amount = {k:v*hold[k] for k,v in today_inf.items() if k in hold.keys()} # 更新capital持有总资产
            hold_amount = {k: hold_amount[k] for k in hold_amount if not np.isnan(hold_amount[k])}
            
            hold_cap = sum(hold_amount.values())
            result.capital.iloc[i+1] = hold_cap +  result.cash.iloc[i+1] 
            
            result.turn_over.iloc[i+1] = (sell_cash + buy_cash) / result.capital.iloc[i+1] # 当日换手率
            #print(date_list[i+1],'FINISH')
            #print(result)
    
    ## 计算每日的return 非累计
    result['return'] = (result['capital'] - result['capital'].shift(1)) / result['capital'].shift(1)
    daily_return = result['return'].iloc[1:].astype(float)
    cum_return = list(epc.cum_returns(daily_return))   # 累计收益率
    #print(daily_return)
    
    ## 画图
    import tushare as ts
    pro = ts.pro_api()
    st_date = date_list[0].strftime('%Y%m%d')
    end_date = date_list[-1].strftime('%Y%m%d')
    
    df = pro.index_daily(ts_code='000300.SH', start_date=st_date, end_date=end_date)
    df.sort_values('trade_date',inplace = True)
    df['open_cumre'] = np.nancumprod(1+(df['open'] - df['open'].shift(1))/df['open'].shift(1))-1
    
    
    date_list = list(map(lambda x:x.date(),date_list))
    fig = plt.figure(figsize = (10,5))
    plt.rcParams['font.family'] = ['Arial Unicode MS']  # window系统要改
    plt.rcParams['axes.unicode_minus']=False
    sns.set(font='Arial Unicode MS',font_scale = 1.2)
    plt.plot(cum_return,color = 'r',label = 'STRATEGY')
    plt.plot(df['open_cumre'].to_list(),color = 'b',label = 'HS300')
    plt.ylabel('累计收益率')
    
    label = [date_list[x*15] for x in range(len(date_list)//15)]
    plt.xticks([i*15 for i in range(len(label))],label,rotation = 30)
    plt.legend()
    ## 指标计算
    print('累计收益率(%):',cum_return[-1]*100)
    print('年化收益率(%):',epc.annual_return(daily_return,period = 'daily')*100)  # 每日非累计的return
    print('最大回撤:',epc.max_drawdown(daily_return))
    print('夏普率:',epc.sharpe_ratio(daily_return,period = 'daily'))
    #print('IR',epc.information_ratio(returns=returns, factor_returns=benchmark_returns))
    
    return result,cum_return

# %% [markdown]
# #### XGBOOST生成信号回测

# %%
y_re = pd.DataFrame(y_test)
y_re['compare'] = list(y_pred)
y_re['open'] = X_test['open']
y_re.reset_index(inplace = True)
#y_re.set_index('trade_date',inplace= True)

# %%
y_re['compare'] = y_re.groupby('trade_date')['compare'].apply(lambda x:x/np.sum(x))

# %%
y_re.set_index('trade_date',inplace= True)

# %%
y_re['open_Re_2'] = list(Y_or[Y_or.index.get_level_values(0)>=lim ])
y_re['Re'] = (y_re['Y'] * y_re['open_Re_2']).replace(0,np.nan)

# %%
daily_re = y_re.groupby('trade_date')['Re'].mean()

# %%
np.cumprod(1+daily_re)
# Out:
# trade_date
# 2020-05-06     1.014327
# 2020-05-07     1.031563
# 2020-05-08     1.045246
# 2020-05-11     1.063024
# 2020-05-12     1.078120
# 2020-05-13     1.093637
# 2020-05-14     1.112770
# 2020-05-15     1.132619
# 2020-05-18     1.153982
# 2020-05-19     1.171197
# 2020-05-20     1.191516
# 2020-05-21     1.206520
# 2020-05-22     1.225099
# 2020-05-25     1.244996
# 2020-05-26     1.265188
# 2020-05-27     1.279411
# 2020-05-28     1.311662
# 2020-05-29     1.345582
# 2020-06-01     1.366920
# 2020-06-02     1.390423
# 2020-06-03     1.414019
# 2020-06-04     1.439993
# 2020-06-05     1.463189
# 2020-06-08     1.484152
# 2020-06-09     1.511450
# 2020-06-10     1.545748
# 2020-06-11     1.581092
# 2020-06-12     1.609281
# 2020-06-15     1.634421
# 2020-06-16     1.662388
# 2020-06-17     1.689560
# 2020-06-18     1.722746
# 2020-06-19     1.752487
# 2020-06-22     1.787467
# 2020-06-23     1.819478
# 2020-06-24     1.851998
# 2020-06-29     1.888098
# 2020-06-30     1.931652
# 2020-07-01     2.008627
# 2020-07-02     2.091841
# 2020-07-03     2.218007
# 2020-07-06     2.291855
# 2020-07-07     2.371570
# 2020-07-08     2.441395
# 2020-07-09     2.526575
# 2020-07-10     2.605520
# 2020-07-13     2.673604
# 2020-07-14     2.741504
# 2020-07-15     2.792494
# 2020-07-16     2.875815
# 2020-07-17     2.984522
# 2020-07-20     3.055893
# 2020-07-21     3.113750
# 2020-07-22     3.194825
# 2020-07-23     3.283642
# 2020-07-24     3.356249
# 2020-07-27     3.414458
# 2020-07-28     3.520909
# 2020-07-29     3.611127
# 2020-07-30     3.699591
# 2020-07-31     3.794312
# 2020-08-03     3.857332
# 2020-08-04     3.955971
# 2020-08-05     4.045175
# 2020-08-06     4.150515
# 2020-08-07     4.238659
# 2020-08-10     4.309052
# 2020-08-11     4.378665
# 2020-08-12     4.439920
# 2020-08-13     4.536441
# 2020-08-14     4.637526
# 2020-08-17     4.718260
# 2020-08-18     4.808159
# 2020-08-19     4.892489
# 2020-08-20     4.980614
# 2020-08-21     5.068653
# 2020-08-24     5.163844
# 2020-08-25     5.271316
# 2020-08-26     5.351111
# 2020-08-27     5.491558
# 2020-08-28     5.576242
# 2020-08-31     5.675536
# 2020-09-01     5.782637
# 2020-09-02     5.888538
# 2020-09-03     5.988307
# 2020-09-04     6.070441
# 2020-09-07     6.146222
# 2020-09-08     6.256480
# 2020-09-09     6.376126
# 2020-09-10     6.517028
# 2020-09-11     6.615260
# 2020-09-14     6.716547
# 2020-09-15     6.816732
# 2020-09-16     6.916842
# 2020-09-17     7.117651
# 2020-09-18     7.226247
# 2020-09-21     7.323729
# 2020-09-22     7.459810
# 2020-09-23     7.540702
# 2020-09-24     7.627880
# 2020-09-25     7.722971
# 2020-09-28     7.831549
# 2020-09-29     7.973100
# 2020-09-30     8.136529
# 2020-10-09     8.323319
# 2020-10-12     8.484255
# 2020-10-13     8.618286
# 2020-10-14     8.707672
# 2020-10-15     8.827051
# 2020-10-16     8.934248
# 2020-10-19     9.079651
# 2020-10-20     9.203827
# 2020-10-21     9.321725
# 2020-10-22     9.443377
# 2020-10-23     9.622630
# 2020-10-26     9.791502
# 2020-10-27     9.974385
# 2020-10-28    10.199276
# 2020-10-29    10.391238
# 2020-10-30    10.622712
# 2020-11-02    10.842803
# 2020-11-03    11.047236
# 2020-11-04    11.263332
# 2020-11-05    11.454885
# 2020-11-06    11.773800
# 2020-11-09    11.960188
# 2020-11-10    12.123836
# 2020-11-11    12.312838
# 2020-11-12    12.530183
# 2020-11-13    12.773423
# 2020-11-16    12.993082
# 2020-11-17    13.168524
# 2020-11-18    13.394981
# 2020-11-19    13.669314
# 2020-11-20    13.915257
# 2020-11-23    14.124304
# 2020-11-24    14.311185
# 2020-11-25    14.498746
# 2020-11-26    14.771415
# 2020-11-27    15.001408
# 2020-11-30    15.333309
# 2020-12-01    15.544619
# 2020-12-02    15.776264
# 2020-12-03    16.040398
# 2020-12-04    16.323693
# 2020-12-07    16.496297
# 2020-12-08    16.721052
# 2020-12-09    16.997592
# 2020-12-10    17.283835
# 2020-12-11    17.589834
# 2020-12-14    17.857514
# 2020-12-15    18.139068
# 2020-12-16    18.476780
# 2020-12-17    18.875721
# 2020-12-18    19.221230
# 2020-12-21    19.560110
# 2020-12-22    19.928424
# 2020-12-23    20.260528
# 2020-12-24    20.737343
# 2020-12-25    21.216763
# 2020-12-28    21.592445
# 2020-12-29    22.078013
# 2020-12-30    22.667736
# 2020-12-31    23.328014
# 2021-01-04    24.095987
# 2021-01-05    24.630411
# 2021-01-06    25.473279
# 2021-01-07    26.171959
# 2021-01-08    26.725495
# 2021-01-11    27.518184
# 2021-01-12    28.194918
# 2021-01-13    28.736461
# 2021-01-14    29.252108
# 2021-01-15    29.891477
# 2021-01-18    30.319912
# 2021-01-19    31.047358
# 2021-01-20    31.759898
# 2021-01-21    32.825375
# 2021-01-22    33.744038
# 2021-01-25    34.365386
# 2021-01-26    35.090948
# 2021-01-27    35.730664
# 2021-01-28    36.461719
# Name: Re, dtype: float64

# %%
(result,cum_return) = backtest(y_re)
# Out:
# 累计收益率(%): 487.7806543526732
# 年化收益率(%): 1061.6286689924837
# 最大回撤: -0.03044264232582081
# 夏普率: 17.72061500193965

# %%
np.mean(result.turn_over)
# Out:
# 0.8338961908262319

# %%
cum_return
# Out:
# [-0.0003733333333333366,
#  0.007779935109796465,
#  0.019828128974261894,
#  0.02554461552445919,
#  0.03104319670830291,
#  0.041125886702047865,
#  0.05731947200582699,
#  0.06244122229463356,
#  0.07686664190392967,
#  0.08379773515119826,
#  0.07723567047053259,
#  0.08234763191654193,
#  0.08303347678308626,
#  0.0917550614111935,
#  0.1042646776243159,
#  0.10876182732958184,
#  0.11344013532927644,
#  0.13776614187857672,
#  0.15297914237637755,
#  0.16111928323503477,
#  0.17493172222601894,
#  0.1828884494924814,
#  0.1992657892505818,
#  0.2071733481652096,
#  0.21543626449507514,
#  0.2376145857977383,
#  0.24406341585318447,
#  0.2650497872909825,
#  0.2759916184542648,
#  0.2881148307057242,
#  0.29884188822090385,
#  0.31580556297776075,
#  0.3360425612639255,
#  0.34684580427317235,
#  0.355101047807161,
#  0.36940507920663745,
#  0.37940989355871446,
#  0.39498954829240107,
#  0.4148985929843545,
#  0.4435468740934265,
#  0.489335808846457,
#  0.5670075098937859,
#  0.6121883610194345,
#  0.6528251415376756,
#  0.7094016115700865,
#  0.7205676949960935,
#  0.7666804958187405,
#  0.776731190550193,
#  0.781016973533269,
#  0.7822158916073891,
#  0.8097592743629893,
#  0.8592198693524318,
#  0.8784260230538095,
#  0.9024405321146316,
#  0.8779768326499564,
#  0.8800074016286206,
#  0.9010604100684929,
#  0.910322895347681,
#  0.9923129357374345,
#  0.9316616656336736,
#  0.9716088569215124,
#  1.008120922753534,
#  1.0191692910168455,
#  1.068417887298104,
#  1.0866854759986881,
#  1.1019254008223203,
#  1.1327443617217092,
#  1.1349937839877873,
#  1.1445432516457803,
#  1.1532944676236019,
#  1.1926859356784498,
#  1.2307187824775472,
#  1.260178478163171,
#  1.2608527913142962,
#  1.2841605509676803,
#  1.315927673409358,
#  1.3395112867296852,
#  1.3457820265398421,
#  1.351062073802391,
#  1.3731601323173006,
#  1.4348670064830888,
#  1.4415373707880268,
#  1.461781984745699,
#  1.4759100483856216,
#  1.4787000621659607,
#  1.5075148331736585,
#  1.51137647647124,
#  1.5210441128139576,
#  1.537406564472767,
#  1.5428204610767895,
#  1.5886734209112738,
#  1.6044798256368846,
#  1.6234283674645513,
#  1.6314332946190069,
#  1.6524621175528407,
#  1.720708038570908,
#  1.7253045599999854,
#  1.7345644593609784,
#  1.7478197089032026,
#  1.7562891672843812,
#  1.7659728452031644,
#  1.7823618995121642,
#  1.7996616032937167,
#  1.8353234279336372,
#  1.8769447987692494,
#  1.9335019602714456,
#  1.959162814292478,
#  1.9683417252997475,
#  1.9778965995354243,
#  2.0038895593551906,
#  2.007164620312848,
#  2.0418062258411194,
#  2.0488784892169805,
#  2.0660979406802475,
#  2.072107782445964,
#  2.0954649730047863,
#  2.123971469359315,
#  2.149387156891472,
#  2.230466193147309,
#  2.2387591568086145,
#  2.2743439484573345,
#  2.3315585660291824,
#  2.3769461565830032,
#  2.4179786577175544,
#  2.443351041082216,
#  2.5249683787435897,
#  2.534656531477374,
#  2.5470792966645606,
#  2.5743324110924797,
#  2.599875569583619,
#  2.6404138494682434,
#  2.6580533162704696,
#  2.6763944484136846,
#  2.7399211141954063,
#  2.785682077881901,
#  2.820336043807269,
#  2.838951727426002,
#  2.8418729072003006,
#  2.8711249152097498,
#  2.9130050500350078,
#  2.930796442989123,
#  2.998351498849526,
#  3.0016081707392646,
#  3.023564801995983,
#  3.065950896346963,
#  3.088095025263419,
#  3.1011361927932537,
#  3.108094341603435,
#  3.1440763124004416,
#  3.157459044684966,
#  3.191465781467409,
#  3.221158746466412,
#  3.2451677656992466,
#  3.3060762626684763,
#  3.334374125523026,
#  3.391771498717717,
#  3.4002305390072456,
#  3.4486121761209274,
#  3.473325979966061,
#  3.527855901793033,
#  3.562865892433921,
#  3.598015787845058,
#  3.6769209355245724,
#  3.786640781884267,
#  3.847169305732967,
#  3.9292997733475765,
#  4.019450142486093,
#  4.127332410490982,
#  4.2037602564584065,
#  4.221726667825767,
#  4.356636583510599,
#  4.3923134353654145,
#  4.4139897013866145,
#  4.453034821421908,
#  4.50619930600996,
#  4.524916962655495,
#  4.636521745142186,
#  4.7270132182576186,
#  4.779180428401573,
#  4.827567248025581,
#  4.8582883984463345,
#  4.877806543526732]

# %%
## 换手太高

y_re2 = y_re.copy()
decay_day = 30
trade_day = y_re2.index.to_list()

#or_compare = y_re2['compare'][y_re2.index <= trade_day[decay_day-1]]

y_re2['compare'] = y_re2.groupby('ts_code')['compare'].apply(lambda x :x.rolling(decay_day).mean())
#y_re2['compare'][y_re2.index <= trade_day[decay_day-1]] = or_compare

y_re2.reset_index(inplace = True)
y_re2['compare'] = y_re2.groupby('trade_date')['compare'].apply(lambda x:x/np.sum(x))
y_re2.fillna(0,inplace = True)
y_re2.set_index('trade_date',inplace = True)
y_re2
# Out:
#               ts_code  Y   compare    open  open_Re_2        Re
# trade_date
# 2020-05-06  000001.SZ  0  0.000000   13.76   0.000000  0.000000
# 2020-05-07  000001.SZ  1  0.000000   13.76   0.011628  0.011628
# 2020-05-08  000001.SZ  1  0.000000   13.76   0.002155  0.002155
# 2020-05-11  000001.SZ  0  0.000000   13.92  -0.014337  0.000000
# 2020-05-12  000001.SZ  0  0.000000   13.95  -0.014545  0.000000
# ...               ... ..       ...     ...        ...       ...
# 2021-01-22  688036.SH  1  0.002433  191.01   0.071152  0.071152
# 2021-01-25  688036.SH  0  0.002343  191.00  -0.037050  0.000000
# 2021-01-26  688036.SH  0  0.002478  204.59  -0.051774  0.000000
# 2021-01-27  688036.SH  1  0.003166  197.01   0.000856  0.000856
# 2021-01-28  688036.SH  1  0.003088  186.81   0.069690  0.069690
#
# [85804 rows x 6 columns]

# %%
(result_decay,cum_return_decay) = backtest(y_re2)
# Out:
# 累计收益率(%): 388.3635258337204
# 年化收益率(%): 798.7614975692848
# 最大回撤: -0.0002536050682994073
# 夏普率: 17.67651251323386

# %%
np.mean(result_decay.turn_over)
# Out:
# 0.43988594959544625

# %%
result_decay.to_csv('20190601result.csv')

# %% [markdown]
# #### 单因子回测 （暂时没用）

# %%
factor = 'over_night'
factor_test = FACTOR[['trade_date','ts_code',factor,'close','open']]
factor_test.rename(columns = {factor:'compare'},inplace = True)
factor_test.dropna(axis = 0,inplace = True)

##### 以下为可以对alpha进行的operation，除了必须外，其他可选 #####

## 逆向指标Z-score
#factor_test['compare'] = factor_test.groupby('trade_date')['compare'].apply(lambda x: (- x + np.nanmax(x))/(np.nanmax(x) - np.nanmin(x)))

## 取反
#factor_test['compare'] = -factor_test['compare']

##取正的alpha，在A股市场，个体投资户很难进行做空，因此回测时不做空只做多。（必须）
factor_test['compare'].where(factor_test['compare']>0,0,inplace = True) # 取正的

##分层回测
#factor_test['rank'] =factor_test.groupby('trade_date')['compare'].apply(lambda x :x.rank(method = 'min',ascending =True))
#factor_test['compare'][factor_test['rank'] <= 0]  = 0
#factor_test['compare'][factor_test['rank'] > 500]  = 0
#factor_test['compare'][(factor_test['rank'] > 0)&(factor_test['rank'] <= 50)]  = 1
#print(factor_test)

##每日alpha合为一（必须）
factor_test['compare'] = factor_test.groupby('trade_date')['compare'].apply(lambda x: x/ sum(x))

factor_test.set_index('trade_date',inplace = True)
factor_test.sort_index(inplace = True)
factor_test#.dropna(axis = 0, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-629-f5ec3c86a1c3> in <module>
#       1 factor = 'over_night'
# ----> 2 factor_test = FACTOR[['trade_date','ts_code',factor,'close','open']]
#       3 factor_test.rename(columns = {factor:'compare'},inplace = True)
#       4 factor_test.dropna(axis = 0,inplace = True)
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1263             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1264
# -> 1265         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1266         return keyarr, indexer
#    1267
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1313             if raise_missing:
#    1314                 not_found = list(set(key) - set(ax))
# -> 1315                 raise KeyError(f"{not_found} not in index")
#    1316
#    1317             not_found = key[missing_mask]
#
# KeyError: "['trade_date', 'ts_code'] not in index"

# %%
## 回测
(result,cum_return) = backtest(factor_test)
